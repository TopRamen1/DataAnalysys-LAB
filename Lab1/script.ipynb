# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %% [markdown]
# # Excercise 1

# %%
df = pd.read_csv("Data1.csv", index_col=0)

df.plot()
# Out:
# <AxesSubplot:>

# %%
df.hist(bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'theta_1'}>,
#         <AxesSubplot:title={'center':'theta_2'}>],
#        [<AxesSubplot:title={'center':'theta_3'}>,
#         <AxesSubplot:title={'center':'theta_4'}>],
#        [<AxesSubplot:title={'center':'theta_5'}>,
#         <AxesSubplot:title={'center':'theta_6'}>]], dtype=object)

# %%
for c in df.columns:
    df[c].plot.kde()
    plt.title(c)
    plt.show()

# %%
datetime_col = pd.to_datetime(df.index)
mask = datetime_col.year == int(2018)

df_2018 = df[mask]

df_selected = df_2018[["theta_1", "theta_4"]]

df_selected.head
# Out:
# <bound method NDFrame.head of              theta_1   theta_4
# 2018-01-01  0.682693 -0.238530
# 2018-01-02 -0.283107  0.158031
# 2018-01-03  1.572221  0.041347
# 2018-01-04 -1.042981  0.064832
# 2018-01-05 -1.392614 -0.015025
# ...              ...       ...
# 2018-12-27  0.473556  0.076798
# 2018-12-28  1.433117  0.028891
# 2018-12-29  0.285428  0.111482
# 2018-12-30  2.249273 -0.080878
# 2018-12-31  0.316409 -0.150844
#
# [365 rows x 2 columns]>

# %%
df_selected.plot()

df_selected.hist(bins=100)

plt.show()

for c in df_selected.columns:
    df_selected[c].plot.kde()
    plt.title(c)
    plt.show()

# %% [markdown]
# # Excercise 2
